# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Librerías de visualización
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

# Librerías propias
# -----------------------------------------------------------------------
import EDA 

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df = pd.read_csv('../../data/hr_raw_data.csv', index_col=0)

# %% [markdown]
# **VISUALIZACIÓN DE LOS DATOS**

# %%
EDA.visualizacion_datos(df)
# Out:
# VISUALIZACIÓN RÁPIDA DE LOS DATOS:
# ----------------------------------
#   age attrition businesstravel    dailyrate                department  \
# 0  51        No            NaN  2015.722222                       NaN
# 1  52        No            NaN  2063.388889                       NaN
# 2  42        No  travel_rarely  1984.253968   Research & Development
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
#
#    employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0               1                        1       0         NaN
# 1               2                        3       0         NaN
# 2               3                        3       0         NaN
#
#    jobinvolvement  joblevel              jobrole  jobsatisfaction  \
# ...

# %% [markdown]
# **COLUMNAS NULAS DEL DATAFRAME**
#
# Se va a ver cuales columnas tienen valores nulos y cual es el porcentaje de nulos, para posteriormente trabajar con ellos.

# %%
col_nulos = EDA.variables_nulas(df)
# Out:
#                 columna   %_nulos
# 39       numberchildren  100.0000
# 32   yearsincurrentrole   97.9142
# 38      roledepartament   81.4064
# 4            department   81.4064
# 12           hourlyrate   75.5066
# 21               over18   55.8999
# 2        businesstravel   47.7354
# 7        educationfield   46.1263
# 22             overtime   41.4779
# 17        maritalstatus   40.2265
# 28    totalworkingyears   32.7175
# 18        monthlyincome   29.1418
# 35  sameasmonthlyincome   29.1418
# 26        standardhours   20.9178
# 37               salary   16.9845
# 24    performancerating   11.9190
# 30      worklifebalance    6.7938
# Las siguientes columnas tienen valores nulos:
#       - businesstravel
#       - department
#       - educationfield
#       - hourlyrate
#       - maritalstatus
#       - monthlyincome
#       - over18
#       - overtime
#       - performancerating
#       - standardhours
#       - totalworkingyears
#       - worklifebalance
# ...

# %% [markdown]
# --------------------------------

# %% [markdown]
# ## SE HACE DESPUÉS DE LOS NULOS Y OTRAS TRANSFORMACIONES
#
# **DUPLICADOS**
#
# Se ve el número de duplicados que se encuentra en el dataframe y, posteriormente, se eliminan dichos duplicados.

# %%
# EDA.duplicados_ver(df, "employeenumber")

# %%
# df = EDA.func_duplicados(df)

# %% [markdown]
# --------------------------------

# %% [markdown]
# **ESTADÍSTICAS DESCRIPTIVAS BÁSICAS**
#
# Se realiza una breve descripción de las diferentes columnas del dataframe para poder ir conociendo mejor ante que tipo de datos nos encontramos y cuales son los cambios que tenemos que hacerle.

# %%
df.describe().T
# Out:
#                            count         mean         std          min  \
# dailyrate                 1678.0   668.079714  470.787298   104.103175
# distancefromhome          1678.0     4.504172   14.652066   -49.000000
# education                 1678.0     2.932658    1.024270     1.000000
# employeecount             1678.0     1.000000    0.000000     1.000000
# employeenumber            1678.0   809.859952  467.084867     1.000000
# environmentsatisfaction   1678.0     4.264005    6.912695     1.000000
# gender                    1678.0     0.398689    0.489774     0.000000
# hourlyrate                 411.0    83.140768   57.272101    13.012897
# jobinvolvement            1678.0     2.740763    0.710359     1.000000
# joblevel                  1678.0     2.064362    1.099425     1.000000
# jobsatisfaction           1678.0     2.743147    1.105172     1.000000
# numcompaniesworked        1678.0     2.670441    2.501133     0.000000
# ...

# %%
df.describe(include='O').T
# Out:
#                     count unique  \
# age                  1678     54
# attrition            1678      2
# businesstravel        877      3
# department            312      3
# educationfield        904      6
# jobrole              1678   1579
# maritalstatus        1003      5
# monthlyincome        1189    493
# monthlyrate          1678    673
# over18                740      1
# overtime              982      2
# performancerating    1478      2
# standardhours        1327      2
# totalworkingyears    1129     40
# worklifebalance      1564      4
# yearsincurrentrole     35     10
# sameasmonthlyincome  1189    493
# salary               1393    583
# roledepartament       312    301
# remotework           1678      5
#
#                                                                  top  freq
# age                                                               35    88
# attrition                                                         No  1406
# ...

# %% [markdown]
# Se quiere saber las diferentes categorías que tiene las columnas del dataframe con el que se está trabajando.

# %%
EDA.categorias(df)
# Out:
# Las categorías que tenemos para la columna age son:
#              age  count
# 0             35     88
# 1             31     88
# 2             34     86
# 3             29     82
# 4             36     79
# 5             32     66
# 6             30     65
# 7             38     64
# 8             33     63
# 9             40     60
# 10            28     54
# 11            37     54
# 12            27     54
# 13            45     50
# 14            42     50
# 15            41     48
# 16            39     46
# 17            26     46
# 18            43     42
# 19            46     38
# 20            44     34
# 21            50     34
# 22            47     30
# 23            24     29
# 24            25     28
# 25            49     26
# 26            55     25
# 27            51     22
# 28            48     22
# 29            53     20
# 30            54     20
# 31            52     18
# 32            56     18
# 33            21     17
# 34            22     17
# ...

# %% [markdown]
# **IMPUTACIÓN DE LOS DATOS**

# %% [markdown]
# Se quiere imputar los `NaN` de la columna `department`, para ello crearemos un diccionario y utilizaremos la función `imputacion_categorica`.

# %%
# Visualizamos las columnas
df[["jobrole", "department", "roledepartament"]].head(7)
# Out:
#                jobrole                department  \
# 0   resEArch DIREcToR                        NaN
# 1             ManAGeR                        NaN
# 2             ManaGER    Research & Development
# 3   ReseArCH DIrECtOr                        NaN
# 4     sAleS EXECUtIve                        NaN
# 5             MANAger    Research & Development
# 6     Sales ExeCutIVe                        NaN
#
#                         roledepartament
# 0                                   NaN
# 1                                   NaN
# 2   ManaGER  -  Research & Development
# 3                                   NaN
# 4                                   NaN
# 5   MANAger  -  Research & Development
# 6                                   NaN

# %%
# Se pasa a minusculas las columnas que se utilizarán para la imputación para ver los diferentes tipos que hay
# y poder realizar el diccionario. 
lista_minusculas = ["jobrole", "roledepartament"] 
for col in lista_minusculas:
    df[col] = df[col].str.lower()

df["roledepartament"].value_counts()
# Out:
# roledepartament
# sales executive  -  sales                                71
# research scientist  -  research & development            64
# laboratory technician  -  research & development         60
# healthcare representative  -  research & development     27
# manufacturing director  -  research & development        22
# sales representative  -  sales                           17
# research director  -  research & development             16
# human resources  -  human resources                      15
# manager  -  research & development                       14
# manager  -  sales                                         5
# manager  -  human resources                               1
# Name: count, dtype: int64

# %%
# Diccionario roles-departamentos:
roles_dict = {
    "sales executive": "sales",
    "research scientist": "research & development",
    "laboratory technician": "research & development",
    "healthcare representative": "research & development",
    "manufacturing director": "research & development",
    "sales representative": "sales",
    "research director": "research & development",
    "human resources": "human resources",
    "manager": "research & development"  #dejamos solo manager - research & development basándonos en que es el que más veces aparece
}

# %%
df = EDA.imputacion_categorica(df, 'department', 'jobrole', roles_dict)
# Out:
#              jobrole              department
# 0  research director  research & development
# 1            manager  research & development
# 2            manager  research & development
# 3  research director  research & development
# 4    sales executive                   sales
# 5            manager  research & development
# 6    sales executive                   sales
# 7    sales executive                   sales
# 8            manager  research & development
# 9  research director  research & development
# Se han imputado todas las filas de la columna department.

# %%
df = EDA.limpiar(df, 'monthlyincome', ['$', ','], ['', '.'])
# Out:
# Limpiezas aplicada en la columna monthlyincome
# Reemplazado ',' por '.'

# %%
df = EDA.limpiar(df, ['monthlyrate', 'salary'], ['$', ','], ['', '.'])
# Out:
# Limpiezas aplicada en la columna monthlyrate
# Reemplazado ',' por '.'
# Limpiezas aplicada en la columna salary
# Reemplazado ',' por '.'

# %%
df = EDA.columnas_a_eliminar(df, 'over18')
# Out:
# ¡Columnas eliminadas con éxito!
# Se eliminaron las siguientes 1 columnas: ['over18']
# El DataFrame ahora tiene 40 columnas.

# %%
eliminar = ['employeecount', 'standardhours', 'over18']

df = EDA.columnas_a_eliminar(df, eliminar)
# Out:
# ADVERTENCIA: estas columnas no existen en el DataFrame: ['over18']
# ¡Columnas eliminadas con éxito!
# Se eliminaron las siguientes 2 columnas: ['employeecount', 'standardhours']
# El DataFrame ahora tiene 38 columnas.

# %%
cols_a_eliminar = [
    'jobrole_clean', 
    'numberchildren', 
    'roledepartament', 
    'totalworkingyears', 
    'hourlyrate', 
    'employeecount', 
    'standardhours', 
    'over18',
    "sameasmonthlyincome"
]

df = EDA.columnas_a_eliminar(df, cols_a_eliminar)
# Out:
# ADVERTENCIA: estas columnas no existen en el DataFrame: ['jobrole_clean', 'employeecount', 'standardhours', 'over18']
# ¡Columnas eliminadas con éxito!
# Se eliminaron las siguientes 5 columnas: ['numberchildren', 'roledepartament', 'totalworkingyears', 'hourlyrate', 'sameasmonthlyincome']
# El DataFrame ahora tiene 33 columnas.

# %%
mapeo_edad = {
    'forty-seven': 47,
    'fifty-eight': 58,
    'thirty-six': 36,
    'fifty-five': 55,
    'fifty-two': 52,
    'thirty-one': 31,
    'thirty': 30,
    'twenty-six': 26,
    'thirty-seven': 37,
    'thirty-two': 32, 
    'twenty-four':24
}

# %%
df = EDA.imputacion_conversion_datos_numericos(df, 'age', mapeo_edad)
# Out:
# Columna 'age' procesada:
# 0    51
# 1    52
# 2    42
# 3    47
# 4    46
# 5    48
# 6    59
# 7    42
# 8    41
# 9    41
# Name: age, dtype: Int64
# Tipo final: Int64

# %%
def imputacion_conversion_datos_categoricos(df, cols, dic_mapeo):
    """
    hola
    """
    df_copia = df.copy()

    if isinstance(cols, str): 
        cols = [cols]

    for col in cols: 
        df_copia[col] = df_copia[col].replace(dic_mapeo)

        print(f"Columna '{col}' estandarizada.")
        print(f"\nNuevo conteo de '{col}':")
        print(df_copia[col].value_counts())
        print('_' * 100)

    return df_copia

# %%
mapeo_estado_civil = {
    'Marreid': 'Married',  # Corrigiendo el error tipográfico
    'divorced': 'Divorced' # Corrigiendo el uso de minúsculas
}

df = EDA.imputacion_conversion_datos_categoricos(df, 'maritalstatus', mapeo_estado_civil)
# Out:
# Columna 'maritalstatus' estandarizada.
#
# Nuevo conteo de 'maritalstatus':
# maritalstatus
# Married     455
# Single      343
# Divorced    205
# Name: count, dtype: int64
# ____________________________________________________________________________________________________

# %%
# Reemplazar ',' por '.' como separador decimal en la columna 'performancerating'
df = EDA.limpiar(df, 'performancerating', ',', '.')
# Out:
# Limpiezas aplicada en la columna performancerating
# Reemplazado ',' por '.'

# %%
df['attrition'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)
