# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Librerías de visualización
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

# Librerías propias
# -----------------------------------------------------------------------
import EDA 

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df = pd.read_csv('../../data/hr_raw_data.csv', index_col=0)
display(df.head(3)) # miramos cómo nos abre el df
display(df.tail(3))
print('.'*100)
print('Valores aleatorios:')
display(df.sample(3))
# Out:
#   age attrition businesstravel    dailyrate                department  \
# 0  51        No            NaN  2015.722222                       NaN
# 1  52        No            NaN  2063.388889                       NaN
# 2  42        No  travel_rarely  1984.253968   Research & Development
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
#
#    employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0               1                        1       0         NaN
# 1               2                        3       0         NaN
# 2               3                        3       0         NaN
#
#    jobinvolvement  joblevel              jobrole  jobsatisfaction  \
# 0               3         5   resEArch DIREcToR                 3
# ...

# %%
df.info()

# NOTAS:
#-- Nulos: businesstravel, department, educationfield, hourlyrate , maritalstatus, monthlyincome, over18, overtime, performancerating, standardhours, totalworkingyears, worklifebalance, yearsincurrentrole, sameasmonthlyincome, salary, roledepartament , numberchildren.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, 0 to 1677
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1678 non-null   object
#  1   attrition                 1678 non-null   object
#  2   businesstravel            877 non-null    object
#  3   dailyrate                 1678 non-null   float64
#  4   department                312 non-null    object
#  5   distancefromhome          1678 non-null   int64
#  6   education                 1678 non-null   int64
#  7   educationfield            904 non-null    object
#  8   employeecount             1678 non-null   int64
#  9   employeenumber            1678 non-null   int64
#  10  environmentsatisfaction   1678 non-null   int64
#  11  gender                    1678 non-null   int64
#  12  hourlyrate                411 non-null    float64
#  13  jobinvolvement            1678 non-null   int64
# ...

# %%
nulos = df.isnull().sum()/df.shape[0]*100
nulos.sort_values(ascending=False)
# Out:
# numberchildren              100.000000
# yearsincurrentrole           97.914184
# department                   81.406436
# roledepartament              81.406436
# hourlyrate                   75.506555
# over18                       55.899881
# businesstravel               47.735399
# educationfield               46.126341
# overtime                     41.477950
# maritalstatus                40.226460
# totalworkingyears            32.717521
# sameasmonthlyincome          29.141836
# monthlyincome                29.141836
# standardhours                20.917759
# salary                       16.984505
# performancerating            11.918951
# worklifebalance               6.793802
# trainingtimeslastyear         0.000000
# yearsatcompany                0.000000
# relationshipsatisfaction      0.000000
# stockoptionlevel              0.000000
# yearssincelastpromotion       0.000000
# yearswithcurrmanager          0.000000
# datebirth                     0.000000
# ...

# %%
col_nulos = EDA.variables_nulas(df)
#-- Nulos: businesstravel, department, educationfield, hourlyrate , maritalstatus, monthlyincome, over18, overtime, performancerating, standardhours, totalworkingyears, worklifebalance, yearsincurrentrole, sameasmonthlyincome, salary, roledepartament , numberchildren
# Out:
#                 columna     %_nulos
# 2        businesstravel   47.735399
# 4            department   81.406436
# 7        educationfield   46.126341
# 12           hourlyrate   75.506555
# 17        maritalstatus   40.226460
# 18        monthlyincome   29.141836
# 21               over18   55.899881
# 22             overtime   41.477950
# 24    performancerating   11.918951
# 26        standardhours   20.917759
# 28    totalworkingyears   32.717521
# 30      worklifebalance    6.793802
# 32   yearsincurrentrole   97.914184
# 35  sameasmonthlyincome   29.141836
# 37               salary   16.984505
# 38      roledepartament   81.406436
# 39       numberchildren  100.000000
# La siguiente columna tiene valores nulos: businesstravel
# La siguiente columna tiene valores nulos: department
# La siguiente columna tiene valores nulos: educationfield
# La siguiente columna tiene valores nulos: hourlyrate
# La siguiente columna tiene valores nulos: maritalstatus
# ...

# %%
EDA.duplicados_ver(df, "employeenumber")
# Out:
# Número de filas duplicadas: 64
#      age attrition businesstravel    dailyrate department  distancefromhome  \
# 8     41        No            NaN  1712.182540        NaN                 2
# 1656  41        No            NaN  1712.182540        NaN                 2
# 60    36        No            NaN   610.174603        NaN                 5
# 1652  36        No            NaN   610.174603        NaN                 5
# 1676  47        No  travel_rarely  1032.487286        NaN                 4
# ...   ..       ...            ...          ...        ...               ...
# 1638  48        No  travel_rarely   417.960317        NaN                 2
# 1657  45        No  travel_rarely   495.753968        NaN                 2
# 1568  45        No  travel_rarely   495.753968        NaN                 2
# 1671  31        No            NaN   556.256661        NaN                12
# 1607  31        No            NaN   556.256661        NaN                12
#
# ...

# %%
EDA.func_duplicados(df)
# Out:
# El número de filas es de 1678
# El número de duplicados es: 64.
# Borrando duplicados...
# Se han eliminado los duplicados.
# Comprobando que el número de duplicados sea cero.
# Comprobación: 0
# Ahora el número de filas es: 1614

# %%
df.describe().T
# Out:
#                            count         mean         std          min  \
# dailyrate                 1614.0   669.630678  472.353332   104.103175
# distancefromhome          1614.0     4.527261   14.591913   -49.000000
# education                 1614.0     2.925031    1.022357     1.000000
# employeecount             1614.0     1.000000    0.000000     1.000000
# employeenumber            1614.0   807.500000  466.065982     1.000000
# environmentsatisfaction   1614.0     4.294919    6.993559     1.000000
# gender                    1614.0     0.398389    0.489718     0.000000
# hourlyrate                 404.0    83.043441   57.547758    13.012897
# jobinvolvement            1614.0     2.739777    0.711567     1.000000
# joblevel                  1614.0     2.068154    1.101344     1.000000
# jobsatisfaction           1614.0     2.738538    1.106163     1.000000
# numcompaniesworked        1614.0     2.673482    2.506152     0.000000
# ...

# %%
df.describe(include='O').T
# Out:
#                     count unique                       top  freq
# age                  1614     54                        35    84
# attrition            1614      2                        No  1355
# businesstravel        842      3             travel_rarely   586
# department            302      3   Research & Development    196
# educationfield        869      6             Life Sciences   349
# jobrole              1614   1579                  mANager      4
# maritalstatus         963      5                   Married   404
# monthlyincome        1146    493                  4492,84$   224
# monthlyrate          1614    673                 11681,39$   317
# over18                713      1                         Y   713
# overtime              938      2                        No   682
# performancerating    1419      2                       3,0  1205
# standardhours        1276      2                 Part Time   888
# ...

# %%
for col in df.select_dtypes(include='O').columns:
    print(f"Las categorías que tenemos para la columna {col} son:")
    display(df[col].value_counts().reset_index())
    print('_' * 100)
# Out:
# Las categorías que tenemos para la columna age son:
#              age  count
# 0             35     84
# 1             34     83
# 2             31     82
# 3             29     78
# 4             36     74
# 5             32     64
# 6             38     64
# 7             30     63
# 8             33     61
# 9             40     60
# 10            27     54
# 11            37     53
# 12            28     53
# 13            42     50
# 14            45     48
# 15            41     46
# 16            26     45
# 17            39     45
# 18            43     40
# 19            46     38
# 20            44     34
# 21            50     31
# 22            25     27
# 23            24     26
# 24            47     26
# 25            49     25
# 26            55     24
# 27            54     20
# 28            51     20
# 29            53     20
# 30            48     20
# 31            52     18
# 32            56     17
# 33            21     16
# 34            22     16
# ...

# %% [markdown]
# --------------------------------------------------------
# COPIA

# %%
df_copia= df[["jobrole", "department", "roledepartament"]] #chequeamos las columnas
df_copia
# Out:
#                        jobrole                department  \
# 0           resEArch DIREcToR                        NaN
# 1                     ManAGeR                        NaN
# 2                     ManaGER    Research & Development
# 3           ReseArCH DIrECtOr                        NaN
# 4             sAleS EXECUtIve                        NaN
# ...                        ...                       ...
# 1609          saLEs ExeCUTiVe                        NaN
# 1610    LAboRaTOry tECHNiCIAn                        NaN
# 1611          sAlES ExECUTivE                        NaN
# 1612          SaLes ExecUtIVe                        NaN
# 1613   mAnUfactURInG DiRECTOr                        NaN
#
#                            roledepartament
# 0                                      NaN
# 1                                      NaN
# 2      ManaGER  -  Research & Development
# 3                                      NaN
# 4                                      NaN
# ...

# %%
lista_minusculas = ["jobrole", "roledepartament"]  #pasamos a minusculas
for col in lista_minusculas:
    df_copia[col] = df_copia[col].str.lower()
    #print(df_copia[col].unique())
# Out:
# C:\Users\Magdala Pérez Nimo\AppData\Local\Temp\ipykernel_8612\2924442795.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copia[col] = df_copia[col].str.lower()

# %%
df_copia
# Out:
#                        jobrole                department  \
# 0           research director                        NaN
# 1                     manager                        NaN
# 2                     manager    Research & Development
# 3           research director                        NaN
# 4             sales executive                        NaN
# ...                        ...                       ...
# 1609          sales executive                        NaN
# 1610    laboratory technician                        NaN
# 1611          sales executive                        NaN
# 1612          sales executive                        NaN
# 1613   manufacturing director                        NaN
#
#                            roledepartament
# 0                                      NaN
# 1                                      NaN
# 2      manager  -  research & development
# 3                                      NaN
# 4                                      NaN
# ...

# %%
df_copia["roledepartament"].value_counts()
# Out:
# roledepartament
# sales executive  -  sales                                69
# research scientist  -  research & development            62
# laboratory technician  -  research & development         56
# healthcare representative  -  research & development     26
# manufacturing director  -  research & development        22
# sales representative  -  sales                           17
# research director  -  research & development             16
# manager  -  research & development                       14
# human resources  -  human resources                      14
# manager  -  sales                                         5
# manager  -  human resources                               1
# Name: count, dtype: int64

# %%
df_copia["jobrole"].value_counts()
# Out:
# jobrole
# sales executive               369
# research scientist            314
# laboratory technician         278
# manufacturing director        158
# healthcare representative     149
# manager                       111
# sales representative           90
# research director              88
# human resources                57
# Name: count, dtype: int64

# %%
df_copia["department"].value_counts()
# Out:
# department
# Research & Development     196
# Sales                       91
# Human Resources             15
# Name: count, dtype: int64

# %%
roles_dict = {
    "sales executive": "sales",
    "research scientist": "research & development",
    "laboratory technician": "research & development",
    "healthcare representative": "research & development",
    "manufacturing director": "research & development",
    "sales representative": "sales",
    "research director": "research & development",
    "human resources": "human resources",
    "manager": "sales"  #dejamos solo manager - sales basándonos en que es el que más veces aparece
}

# %%
#df_copia["department"] = df_copia["jobrole"].map(roles_dict).fillna(df_copia["department"])

# %%
#df_copia['department'].value_counts()

# %%
# Normalizar columna jobrole
df_copia["jobrole_clean"] = df_copia["jobrole"].str.strip().str.lower()
# Normalizar claves del diccionario también
roles_dict_clean = {k.lower().strip(): v for k, v in roles_dict.items()}
# Aplicar el mapping
df_copia["department"] = (
    df_copia["jobrole_clean"].map(roles_dict_clean)
    .fillna(df_copia["department"])
)
# Out:
# C:\Users\Magdala Pérez Nimo\AppData\Local\Temp\ipykernel_8612\892108055.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copia["jobrole_clean"] = df_copia["jobrole"].str.strip().str.lower()
# C:\Users\Magdala Pérez Nimo\AppData\Local\Temp\ipykernel_8612\892108055.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copia["department"] = (

# %%
df_copia
# Out:
#                        jobrole              department  \
# 0           research director   research & development
# 1                     manager                    sales
# 2                     manager                    sales
# 3           research director   research & development
# 4             sales executive                    sales
# ...                        ...                     ...
# 1609          sales executive                    sales
# 1610    laboratory technician   research & development
# 1611          sales executive                    sales
# 1612          sales executive                    sales
# 1613   manufacturing director   research & development
#
#                            roledepartament           jobrole_clean
# 0                                      NaN       research director
# 1                                      NaN                 manager
# 2      manager  -  research & development                  manager
# ...

# %% [markdown]
# FIN COPIA

# %% [markdown]
# -------------------------------------------------------------------------------

# %%
lista_minusculas = ["jobrole", "roledepartament"]  #pasamos a minusculas
for col in lista_minusculas:
    df[col] = df[col].str.lower()

# %%
# Normalizar columna jobrole
df["jobrole_clean"] = df["jobrole"].str.strip().str.lower()
# Normalizar claves del diccionario también
roles_dict_clean = {k.lower().strip(): v for k, v in roles_dict.items()}
# Aplicar el mapping
df["department"] = (
    df["jobrole_clean"].map(roles_dict_clean)
    .fillna(df["department"])
)

# %%
df.head(10)
# Out:
#   age attrition     businesstravel    dailyrate              department  \
# 0  51        No                NaN  2015.722222  research & development
# 1  52        No                NaN  2063.388889                   sales
# 2  42        No      travel_rarely  1984.253968                   sales
# 3  47        No      travel_rarely  1771.404762  research & development
# 4  46        No                NaN  1582.771346                   sales
# 5  48        No                NaN  1771.920635                   sales
# 6  59        No                NaN  1032.487286                   sales
# 7  42        No      travel_rarely   556.256661                   sales
# 8  41        No                NaN  1712.182540                   sales
# 9  41        No  travel_frequently  1973.984127  research & development
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# ...

# %% [markdown]
# ### **ATENCIÓN**
#
# - Eliminar la columna nueva creada `jobrole_clean` y ya se prodría eliminar `roledepartament`.
# - Hay que tener en cuenta que las columnas `jobrole` y `roledepartament` está todo en minuscula.
